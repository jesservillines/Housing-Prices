# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# modeling imports
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNetCV, ElasticNet
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn import decomposition

#set_style
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Import raw training data

# %%
ames = pd.read_csv('../datasets/test.csv')

# %%
ames.shape
# Out:
# (878, 80)

# %% [markdown]
# #### Apply same transformations as to model training data

# %%
#want to change columns names to lower/snake_case so a little easier to work with
ames.columns = ames.columns.str.lower().str.replace(' ', '_')

# %%
#increase pandas default max_rows so I can view all columns at once
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ### Nulls

# %% [markdown]
# #### Lot Frontage

# %%
#replace np.nan with average for lot_config of that type
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'Corner'), 'lot_frontage'] = 83.25
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'CulDSac'), 'lot_frontage'] = 54.734375        
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'FR2'), 'lot_frontage'] = 60.836735        
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'FR3'), 'lot_frontage'] = 87.000000        
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'Inside'), 'lot_frontage'] = 66.759571

# %% [markdown]
# #### Alley

# %%
ames['alley'] = ames['alley'].replace(np.nan, 'NA')

# %% [markdown]
# #### Masonry veneer type and area

# %%
ames['mas_vnr_type'] = ames['mas_vnr_type'].replace(np.nan, 'None') #replace masonry np.nan with None
ames['mas_vnr_area'] = ames['mas_vnr_area'].replace(np.nan, 0) #replace masonry np.nan with 0

# %% [markdown]
# #### Basement related:
# * bsmt_qual (Evaluates the height of the basement),
# * bsmt_cond (Evaluates the general condition of the basement),
# * bsmt_exposure (Refers to walkout or garden level walls)
# * bsmtfin_type_1
# * bsmtfin_sf_1
# * bsmtfin_type_2
# * bsmtfin_sf_2
# * bsmt_unf_sf
# * total_bsmt_sf
# * bsmt_full_bath
# * bsmt_half_bath

# %%
#these all receive an NA if no basement
basement_to_na = ['bsmt_qual', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 
       'bsmtfin_type_2']

#these receive 0sqft if basement is NA
basement_to_zero = ['bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf', 'bsmtfin_sf_1', 'bsmt_full_bath',
       'bsmt_half_bath']

for i in basement_to_na:
    ames[i] = ames[i].replace(np.nan, 'NA')

# %%
#set basement sqft to 0 IF basement is NA, else drop as incomplete basement data and only 1 null record for each    
for i in basement_to_zero:
    ames[i] = ames[i].replace(np.nan, 0)

# %% [markdown]
# #### fireplace_qu

# %%
ames['fireplace_qu'] = ames['fireplace_qu'].replace(np.nan, 'NA') #NA for 'No Fireplace'

# %% [markdown]
# #### Garage related:
# * garage_type
# * garage_yr_blt
# * garage_finish
# * garage_cars
# * garage_area
# * garage_qual
# * garage_cond

# %%
#create two lists, one for catagorical and one for numeric

garage_to_na = ['garage_type','garage_finish','garage_qual','garage_cond']
garage_to_0 = ['garage_yr_blt','garage_cars', 'garage_area']

for i in garage_to_na:
    ames[i] = ames[i].replace(np.nan, 'NA')

# %%
for i in garage_to_0:
    ames[i] = ames[i].replace(np.nan, 0)

# %% [markdown]
# #### pool_qc

# %%
for i in ames[(ames['pool_qc'].isna()) & (ames['pool_area'] == 0)]:
    ames['pool_qc'] = ames['pool_qc'].replace(np.nan, 'NA')

# %% [markdown]
# #### fence

# %%
ames['fence'] = ames['fence'].replace(np.nan, 'NA')

# %% [markdown]
# #### misc_feature

# %%
for i in ames[(ames['misc_feature'].isna()) & (ames['misc_val'] == 0)]:
    ames['misc_feature'] = ames['misc_feature'].replace(np.nan, 'NA')

# %% [markdown]
# ### Final Null Check

# %%
ames.isnull().sum()
# Out:
# id                 0
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_qual          0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         1
# 1st_flr_sf         0
# 2nd_flr_sf         0
# low_qual_fin_sf    0
# gr_liv_area        0
# bsmt_full_bath     0
# bsmt_half_bath     0
# full_bath          0
# half_bath          0
# bedroom_abvgr      0
# kitchen_abvgr      0
# kitchen_qual       0
# totrms_abvgrd      0
# functional         0
# fireplaces         0
# fireplace_qu       0
# garage_type        0
# garage_yr_blt      0
# garage_finish      0
# garage_cars        0
# garage_area        0
# garage_qual        0
# garage_cond        0
# paved_drive        0
# wood_deck_sf       0
# open_porch_sf      0
# enclosed_porch     0
# 3ssn_porch         0
# screen_porch       0
# pool_area          0
# pool_qc            0
# fence              0
# misc_feature       0
# misc_val           0
# mo_sold            0
# yr_sold            0
# sale_type          0
# dtype: int64

# %%
#catch anything that was missed, 
ames.fillna(0,inplace= True)

# %% [markdown]
# ## Data Transformations to get model features

# %%
#columns I want to replace values in
ames_ordinal_str_columns = ames[['lot_shape','utilities','land_slope','exter_qual', 
                 'exter_cond','bsmt_qual',
       'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1','bsmtfin_type_2','heating_qc','electrical','kitchen_qual',
                'functional','fireplace_qu','garage_finish','garage_qual','garage_cond','paved_drive','pool_qc','fence']]

dict_ordinal = {
    #overall_qual, overall_cond,exter_qual,exter_cond,bsmt_qual,bsmt_cond,bsmt_exposure,heatingqc,kitchenqual
    #firplacequ,garage_qual,garage_cond,pool_qc,fence
    'Ex': 5,
    'Gd': 4,
    'TA': 3,
    'Fa': 2,
    'Po': 1,
    'NA': 0,
     #lot_shape
    'Reg':4,
    'IR1':3,
    'IR2':2,
    'IR3':1,
    #utilities
    'AllPub':4,
    'NoSewr':3,
    'NoSeWa':2,
    'ELO':1,
    #land_slope
    'Gtl':3,
    'Mod':2,
    'Sev':1,
    #bsmt_exposure
    'Av': 3,
    'Mn': 2,
    'No': 1,
    #bsmtfin_type_1, bsmtfin_type_1
    'GLQ':6,
    'ALQ':5,
    'BLQ':4,
    'Rec':3,
    'LwQ':2,
    'Unf':1,
    #Electrical
    'SBrkr':1,
    'FuseA':0,
    'FuseF':0,
    'FuseP':0,
    'Mix':0,
    #Functional
    'Typ':1,
    'Min1':0,
    'Min2':0,
    'Mod':0,
    'Maj1':0,
    'Maj2':0,
    'Sev':0,
    'Sal':0,
    #garage_finish    
    'Fin': 3,
    'RFn': 2,
    'Unf':1,
    #paved_drive
    'Y' : 2,
    'P' : 1,
    'N' : 0,
    #fence
    'GdPrv':4,
    'MnPrv':3,
    'GdWo':2,
    'MnWw':1   
}

#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#Create neighborhood ranking
ames['neighborhood_order'] = ames['neighborhood']
ames_ordinal_str_columns = ames[['neighborhood_order']]

dict_ordinal = {
    'MeadowV': 1,
    'IDOTRR' : 1,
    'BrDale' : 1,
    'OldTown': 1,
    'BrkSide': 1,
    'Edwards': 1,
    'SWISU': 1,
    'Landmrk':2,
    'Sawyer':2,
    'NPkVill':2,
    'Blueste':2,
    'NAmes':2,
    'Mitchel':2,
    'SawyerW':2,
    'Greens':3,
    'Gilbert':3,
    'NWAmes':3,
    'Blmngtn':3,
    'CollgCr':3,
    'Crawfor':3,
    'ClearCr':3,
    'Somerst':4,
    'Timber':4,
    'Veenker':4,
    'GrnHill':4,
    'StoneBr':4,
    'NoRidge':4,
    'NridgHt':4,
        }

for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#Type of sale
ames['sale_type_order'] = ames['sale_type']
ames_ordinal_str_columns = ames[['sale_type_order']]

dict_ordinal = {
   'ConLw':1,
    'Oth':1,
    'ConLD':1,
    'COD':1,
    'WD':2,
    'WD ':2,
    'CWD':3,
    'ConLI':3,
    'Con':3,
    'New':3
        }

#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
ames['yr*rem'] = ames['year_remod/add'] * ames['year_built']

# %%
ames['basement_overall'] = ames['bsmt_qual'] *ames['bsmt_exposure']

# %%
ames['bsmt_type*sf_all'] = (ames['bsmtfin_type_1']*ames['bsmtfin_sf_1']) + (ames['bsmtfin_type_2']*ames['bsmtfin_sf_2']) #quality*sf interaction variable

# %%
ames['garage_qual*cond'] = ames['garage_qual']*ames['garage_cond']

# %%
 #this is the shop variable
ames['garage_fin*sqft'] = ames['garage_area']*ames['garage_finish']

# %%
#total finished sqft above ground
ames['quality_above_sqft'] = (ames['1st_flr_sf']+ames['2nd_flr_sf']) - ames['low_qual_fin_sf']

# %%
#combine basment baths
ames['bsmt_baths'] = ames['bsmt_full_bath']+(ames['bsmt_half_bath']/2)

# %%
#combine upstairs baths
ames['above_baths'] = ames['full_bath']+(ames['half_bath']/2)

# %%
#I like this all bath feature, more how I think about baths in a home.
ames['all_baths'] = ames['above_baths'] + ames['bsmt_baths']

# %%
#sqft per room w/o baths. This performs better than with baths.
ames['room_size'] = ames['gr_liv_area'] / (ames['totrms_abvgrd'])

# %%
#combine different porches as a measure of developed outside space for houses. 
ames['developed_outside_sf'] = ames['open_porch_sf']+ ames['screen_porch'] + ames['enclosed_porch'] +ames['3ssn_porch'] +ames['wood_deck_sf']

# %%
#dummy for if house has masonry or not
ames['mas_vnr_type_dummy'] = ames['mas_vnr_type']
ames_ordinal_str_columns = ames[['mas_vnr_type_dummy']]

dict_ordinal = {
   'BrkCmn':1,
    'None':0,
    'CBlock':1,
    'BrkFace':1,
    'Stone':1,   
        }

#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#age of property at time of sale
ames['age'] = ames['yr_sold'] - ames['year_built']

# %%
#dummy for if property was remodeled
ames['was_remodeled'] =  ames['year_remod/add'] - ames['year_built'] 
ames['was_remodeled'] = [1 if i> 0 else 0 for i in ames['was_remodeled']];

# %%
#dummy for if property is residential
ames['is_residential'] = ames['ms_zoning']
ames_ordinal_str_columns = ames[['is_residential']]

dict_ordinal = {
   'A (agr)':0,
    'I (all)':0,
    'C (all)':0,
    'RM':1,
    'RH':1,
    'RL':1,
    'FV':1,
        }

#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#2 if by positive feature, 1 if normal, 0 if negative feature. 
ames['positive_condition1'] = ames['condition_1']
ames['positive_condition2'] = ames['condition_2']
ames_ordinal_str_columns = ames[['positive_condition2', 'positive_condition1']]


dict_ordinal = {
   'Artery':0,
    'RRNe':0,
    'RRAe':0,
    'Feedr':0,
    'RRAn':0,
    'Norm':1,
    'RRNn':0,
    'PosN':2,
    'PosA':2,
        }

#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#combine conditions for a local_condition column
ames['local_conditions'] = ames['positive_condition1']+ames['positive_condition2']

# %%
#Order Exterior house features 
ames['exterior_ordinal1'] = ames['exterior_1st']
ames['exterior_ordinal2'] = ames['exterior_2nd']
ames_ordinal_str_columns = ames[['exterior_ordinal2', 'exterior_ordinal1']]

dict_ordinal = {
    'AsphShn':1,
    'CBlock':1,
    'AsbShng':1,
    'Brk Cmn':2,
    'BrkComm':2,
     'Stucco':2,
    'PreCast':2,
    'Other':3,
    'Wd Shng':3,
    'Wd Sdng':3,
    'MetalSd':3,
    'WdShing':3,
    'HdBoard':3,      
    'Plywood':4,
    'BrkFace':5,       
    'VinylSd':5,
    'CmentBd':5,
    'CemntBd':5,
    'Stone':5,    
    'ImStucc':5,    
        }
#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#combine external ordered house features
ames['external_feature'] = ames['exterior_ordinal1'] + ames['exterior_ordinal2']

# %%
# if a house is single story or two story. This will be used to test an intercation between building type and floors, but is not very useful on its on.
ames['house_style_ordinal'] = ames['house_style'] 
ames_ordinal_str_columns = ames[['house_style_ordinal']]

dict_ordinal = {
    '1.5Unf':0,
    '1.5Fin':0,
    'SFoyer':0,
    'SLvl':0,
    '1Story':0,
     '2.5Unf':1,
    '2Story':1,
    '2.5Fin':1    
        }
#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
# trying to split into rental and purchase types. Not sure if this does this well, but I am curious how this interacts with the above 1/2 story feature. 
ames['bldg_type_order'] = ames['bldg_type'] 
ames_ordinal_str_columns = ames[['bldg_type_order']]

dict_ordinal = {
    '2fmCon':0,
    'Twnhs':0,
    'SFoyer':0,
    'Duplex':0,
    '1Fam':1,
     'TwnhsE':1,   
        }
#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
ames = pd.get_dummies(data = ames, columns=['bldg_type'], drop_first=True)

# %%
# dummy for hip/nicer roof styles
ames['is_hip_roof'] = ames['roof_style'] 
ames_ordinal_str_columns = ames[['is_hip_roof']]

dict_ordinal = {
    'Gambrel':0,
    'Mansard':0,
    'Gable':0,
    'Flat':1,
    'Shed':1,
     'Hip':1,   
        }
#loop to get the job done
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#set ames_eval to the features wanted for model
ames_eval = ames[['id','age','neighborhood_order','local_conditions','was_remodeled','overall_qual',
                  'exter_qual','external_feature','bldg_type_TwnhsE','bldg_type_Twnhs','bldg_type_2fmCon', 'is_hip_roof',
                  'mas_vnr_area',  
                  'functional', 'lot_frontage', 'lot_area','developed_outside_sf'
                  ,'garage_fin*sqft','garage_cars', 'paved_drive',
                 'bsmt_qual','bsmt_type*sf_all', 'bsmt_exposure',
                 'heating_qc','kitchen_qual', 'fireplace_qu', 
                 'quality_above_sqft', 'totrms_abvgrd', 'room_size']]

# %%
ames_eval.to_csv('../datasets/ames_test_clean.csv', index = False)

# %% [markdown]
# # LassoCV Model

# %%
ames_clean = pd.read_csv('../datasets/ames_clean_v8.csv')

# %%
X_train = ames_clean.drop(columns=['saleprice'])
y_train = ames_clean['saleprice']
X_test = ames_eval.drop(columns= ['id'])

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (2033, 28)
# (2033,)
# (878, 28)

# %%
pipe_power = Pipeline([
    #('poly', PolynomialFeatures()), #uncomment me to release to power
    ('sc', StandardScaler()),
    ('lassocv', Lasso())
])

# %%
lasso_params1 = {'lassocv__alpha':np.logspace(-1, 4, 75),
               'lassocv__max_iter':[10000],
                 #'lassocv__tol':[.2]
                }

# %%
pipe_gridsearch = GridSearchCV(
                                pipe_power, 
                                param_grid=lasso_params1,
                            )

# %%
pipe_gridsearch.fit(X_train, y_train)
pipe_gridsearch.best_estimator_
# Out:
# Pipeline(steps=[('sc', StandardScaler()),
#                 ('lassocv', Lasso(alpha=0.1365007806546014, max_iter=10000))])

# %%
pipe_gridsearch.best_score_
# Out:
# 0.8922291043238555

# %%
X_test.shape
# Out:
# (878, 28)

# %%
preds_lasso = pipe_gridsearch.predict(X_test)

# %%
ames_eval['saleprice_lasso'] = preds_lasso
# Out:
# <ipython-input-97-eb080e13e9d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ames_eval['saleprice'] = preds

# %%
lasso_submission = ames_eval[['id', 'saleprice_lasso']]

# %%
lasso_submission.head(3)
# Out:
#      id      saleprice
# 0  2658  129231.551389
# 1  2718  163512.812872
# 2  2414  224013.708144

# %%
submission.to_csv('../datasets/_kaggle_submission_lasso.csv', index = False) 
#submission.to_csv('../datasets/submission_poly_lasso_iteration_4.csv', index = False) #THIS IS THE BEST SCORE YET!!!! #Uncomment me and polyfeatures to score

# %% [markdown]
# ## Lasso Coef_ Evaluation

# %%
sc_lasso = StandardScaler()
sc_lasso.fit_transform(X_train)
# Out:
# array([[-0.07300932, -0.35530817, -2.20997115, ...,  0.00951839,
#         -0.26508589,  0.3421764 ],
#        [-0.77235568, -0.35530817,  0.26680468, ...,  1.37130231,
#          1.05904093,  0.76130187],
#        [ 0.69294147, -0.35530817,  0.26680468, ..., -0.88421849,
#         -0.9271493 , -0.44242649],
#        ...,
#        [ 1.49219446,  0.58401759,  0.26680468, ...,  0.92866959,
#          1.72110434, -0.41659594],
#        [ 0.55973263, -0.35530817,  0.26680468, ..., -0.58136452,
#         -0.26508589, -0.69725478],
#        [-0.8389601 ,  0.58401759,  0.26680468, ...,  0.69782286,
#          0.39697752,  0.59285335]])

# %%
lasso_lasso= Lasso(alpha = .1, max_iter=10000)

# %%
lasso_lasso.fit(X_train, y_train)
lasso_lasso.score(X_train, y_train)
# Out:
# 0.8967216783723705

# %%
pd.DataFrame(list(zip(X_train.columns, lasso_lasso.coef_)))
# Out:
#                        0             1
# 0                    age    -38.855870
# 1     neighborhood_order   7191.034989
# 2       local_conditions   8198.644343
# 3          was_remodeled   5189.658465
# 4           overall_qual  10130.028208
# 5             exter_qual  11984.221302
# 6       external_feature    953.476589
# 7       bldg_type_TwnhsE -12061.240406
# 8        bldg_type_Twnhs -13803.072400
# 9       bldg_type_2fmCon  -7155.502373
# 10           is_hip_roof   7034.191125
# 11          mas_vnr_area     22.716478
# 12            functional  10940.412872
# 13          lot_frontage    132.492339
# 14              lot_area      0.581401
# 15  developed_outside_sf     15.485809
# 16       garage_fin*sqft      8.781970
# 17           garage_cars   1715.318285
# 18           paved_drive    629.479760
# 19             bsmt_qual   1804.752193
# 20      bsmt_type*sf_all      5.011340
# 21         bsmt_exposure   3001.944966
# 22            heating_qc   1593.515479
# 23          kitchen_qual   9909.093155
# 24          fireplace_qu   2060.551401
# 25    quality_above_sqft     36.699203
# 26         totrms_abvgrd   1423.243854
# 27             room_size     54.713138

# %% [markdown]
# ## LassoCV with Polynomial Features coef_ evaluation.

# %%
# Instantiate our PolynomialFeatures object to create all two-way terms.
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)

# Fit and transform our X data.
X_overfit = poly.fit_transform(X_train)

# %%
#Uncomment to review all features that were created
#poly.get_feature_names(X_train.columns)

# %%
X_overfit.shape #there are a lot of them
# Out:
# (2033, 434)

# %%
#scale
sc_ =  StandardScaler()
sc_.fit_transform(X_overfit)
# Out:
# array([[-0.07300932, -0.35530817, -2.20997115, ..., -0.33972273,
#         -0.01287683,  0.23670371],
#        [-0.77235568, -0.35530817,  0.26680468, ...,  0.97295558,
#          1.35198473,  0.6643518 ],
#        [ 0.69294147, -0.35530817,  0.26680468, ..., -0.85541779,
#         -0.90863356, -0.47961316],
#        ...,
#        [ 1.49219446,  0.58401759,  0.26680468, ...,  1.76993884,
#          0.90835165, -0.45777889],
#        [ 0.55973263, -0.35530817,  0.26680468, ..., -0.33972273,
#         -0.60509514, -0.68863735],
#        [-0.8389601 ,  0.58401759,  0.26680468, ...,  0.26973505,
#          0.67698321,  0.48871163]])

# %%
#alpha based on trial run.
lasso = Lasso(alpha=115.13953993264481,max_iter=10000, tol=.1)
lasso.fit(X_overfit,y_train)
lasso.score(X_overfit, y_train)
# Out:
# 0.9006830869090925

# %%
#increase pandas default max_rows so I can view all coef_ columns at once
pd.options.display.max_rows = 600

# %%
lasso_coef = lasso.coef_
poly_columns = poly.get_feature_names(X_train.columns)
pd.DataFrame(list(zip(poly_columns, lasso_coef)))
# Out:
#                                            0             1
# 0                                        age  -1318.034250
# 1                         neighborhood_order  16776.424134
# 2                           local_conditions   6309.356558
# 3                              was_remodeled  28057.792504
# 4                               overall_qual  14142.568868
# 5                                 exter_qual   1297.259004
# 6                           external_feature  -3177.375235
# 7                           bldg_type_TwnhsE -30736.607865
# 8                            bldg_type_Twnhs -44882.461730
# 9                           bldg_type_2fmCon   2622.236699
# 10                               is_hip_roof  20610.495344
# 11                              mas_vnr_area     53.487034
# 12                                functional  -5465.425976
# 13                              lot_frontage    255.231721
# 14                                  lot_area      1.015367
# 15                      developed_outside_sf     61.994408
# 16                           garage_fin*sqft     -1.490718
# 17                               garage_cars  -1020.237400
# 18                               paved_drive  -7950.344282
# 19                                 bsmt_qual  -1227.935795
# 20                          bsmt_type*sf_all      3.035028
# 21                             bsmt_exposure   -136.492327
# 22                                heating_qc  -1369.771611
# 23                              kitchen_qual   2461.889115
# 24                              fireplace_qu   2029.868212
# 25                        quality_above_sqft     17.882794
# 26                             totrms_abvgrd    565.751416
# 27                                 room_size      4.980601
# 28                                     age^2      7.469018
# 29                    age neighborhood_order    -52.746569
# 30                      age local_conditions     48.450948
# 31                         age was_remodeled   -121.528229
# 32                          age overall_qual     16.926492
# 33                            age exter_qual     18.480104
# 34                      age external_feature     17.767509
# 35                      age bldg_type_TwnhsE   1138.155543
# 36                       age bldg_type_Twnhs   1440.049731
# 37                      age bldg_type_2fmCon   -254.529532
# 38                           age is_hip_roof   -346.698821
# 39                          age mas_vnr_area     -1.119838
# 40                            age functional     32.969956
# 41                          age lot_frontage     -1.054585
# 42                              age lot_area     -0.002248
# 43                  age developed_outside_sf     -0.323070
# 44                       age garage_fin*sqft      0.164052
# 45                           age garage_cars     34.107113
# 46                           age paved_drive     92.077221
# 47                             age bsmt_qual    -29.108535
# 48                      age bsmt_type*sf_all      0.016854
# 49                         age bsmt_exposure    -25.731961
# 50                            age heating_qc     13.308790
# 51                          age kitchen_qual    -19.952499
# 52                          age fireplace_qu    -12.536856
# 53                    age quality_above_sqft      0.009656
# 54                         age totrms_abvgrd      0.402019
# 55                             age room_size      0.031883
# 56                      neighborhood_order^2   -217.183326
# 57       neighborhood_order local_conditions   -145.226150
# 58          neighborhood_order was_remodeled  -6263.632185
# 59           neighborhood_order overall_qual    409.680128
# 60             neighborhood_order exter_qual    119.176063
# 61       neighborhood_order external_feature     47.325040
# 62       neighborhood_order bldg_type_TwnhsE   1578.467581
# 63        neighborhood_order bldg_type_Twnhs   -184.150236
# 64       neighborhood_order bldg_type_2fmCon      0.000000
# 65            neighborhood_order is_hip_roof    121.335554
# 66           neighborhood_order mas_vnr_area      1.576880
# 67             neighborhood_order functional  -1866.634150
# 68           neighborhood_order lot_frontage     -4.623370
# 69               neighborhood_order lot_area     -0.030649
# 70   neighborhood_order developed_outside_sf     -0.805171
# 71        neighborhood_order garage_fin*sqft      2.246694
# 72            neighborhood_order garage_cars   -650.821578
# 73            neighborhood_order paved_drive   -987.404653
# 74              neighborhood_order bsmt_qual    216.475046
# 75       neighborhood_order bsmt_type*sf_all      0.477489
# 76          neighborhood_order bsmt_exposure     99.267182
# 77             neighborhood_order heating_qc   -470.539401
# 78           neighborhood_order kitchen_qual     91.315196
# 79           neighborhood_order fireplace_qu    329.935719
# 80     neighborhood_order quality_above_sqft      0.401089
# 81          neighborhood_order totrms_abvgrd   -172.480636
# 82              neighborhood_order room_size     -4.554544
# 83                        local_conditions^2   -166.452841
# 84            local_conditions was_remodeled  -1452.285280
# 85             local_conditions overall_qual   -212.172683
# 86               local_conditions exter_qual   1247.322748
# 87         local_conditions external_feature    465.476995
# 88         local_conditions bldg_type_TwnhsE    447.933037
# 89          local_conditions bldg_type_Twnhs     -0.000000
# 90         local_conditions bldg_type_2fmCon      0.000000
# 91              local_conditions is_hip_roof  -1038.844866
# 92             local_conditions mas_vnr_area     -4.273190
# 93               local_conditions functional     -0.000000
# 94             local_conditions lot_frontage    -36.268304
# 95                 local_conditions lot_area      0.023608
# 96     local_conditions developed_outside_sf     -6.587550
# 97          local_conditions garage_fin*sqft      1.914790
# 98              local_conditions garage_cars     -0.000000
# 99              local_conditions paved_drive    219.693701
# 100               local_conditions bsmt_qual    -93.898141
# 101        local_conditions bsmt_type*sf_all      0.230632
# 102           local_conditions bsmt_exposure    538.351730
# 103              local_conditions heating_qc     45.848413
# 104            local_conditions kitchen_qual   -211.468291
# 105            local_conditions fireplace_qu     53.351714
# 106      local_conditions quality_above_sqft      2.384901
# 107           local_conditions totrms_abvgrd   -247.945578
# 108               local_conditions room_size    -12.519253
# 109                          was_remodeled^2     -0.000000
# 110               was_remodeled overall_qual   -101.675256
# 111                 was_remodeled exter_qual    205.805728
# 112           was_remodeled external_feature     80.123403
# 113           was_remodeled bldg_type_TwnhsE    529.375169
# 114            was_remodeled bldg_type_Twnhs     -0.000000
# 115           was_remodeled bldg_type_2fmCon      0.000000
# 116                was_remodeled is_hip_roof     -0.000000
# 117               was_remodeled mas_vnr_area     -0.397167
# 118                 was_remodeled functional    461.311321
# 119               was_remodeled lot_frontage    -14.533162
# 120                   was_remodeled lot_area     -0.073423
# 121       was_remodeled developed_outside_sf      4.337364
# 122            was_remodeled garage_fin*sqft     -1.408183
# 123                was_remodeled garage_cars    561.183185
# 124                was_remodeled paved_drive    401.535663
# 125                  was_remodeled bsmt_qual      0.000000
# 126           was_remodeled bsmt_type*sf_all     -0.664242
# 127              was_remodeled bsmt_exposure    504.794218
# 128                 was_remodeled heating_qc    414.148056
# 129               was_remodeled kitchen_qual      0.000000
# 130               was_remodeled fireplace_qu    754.962864
# 131         was_remodeled quality_above_sqft      0.546432
# 132              was_remodeled totrms_abvgrd   -193.002923
# 133                  was_remodeled room_size      0.141490
# 134                           overall_qual^2   -159.267271
# 135                  overall_qual exter_qual    148.851155
# 136            overall_qual external_feature     41.730785
# 137            overall_qual bldg_type_TwnhsE     -0.000000
# 138             overall_qual bldg_type_Twnhs     -0.000000
# 139            overall_qual bldg_type_2fmCon    843.878559
# 140                 overall_qual is_hip_roof     -0.000000
# 141                overall_qual mas_vnr_area      0.323745
# 142                  overall_qual functional   -101.514481
# 143                overall_qual lot_frontage     -1.935191
# 144                    overall_qual lot_area      0.001733
# 145        overall_qual developed_outside_sf     -1.101770
# 146             overall_qual garage_fin*sqft      0.325130
# 147                 overall_qual garage_cars     -1.510922
# 148                 overall_qual paved_drive   -247.489402
# 149                   overall_qual bsmt_qual      8.217751
# 150            overall_qual bsmt_type*sf_all      0.050292
# 151               overall_qual bsmt_exposure     74.375581
# 152                  overall_qual heating_qc    -37.652063
# 153                overall_qual kitchen_qual     14.877266
# 154                overall_qual fireplace_qu     10.734259
# 155          overall_qual quality_above_sqft      0.614083
# 156               overall_qual totrms_abvgrd    -82.495067
# 157                   overall_qual room_size     -2.583991
# 158                             exter_qual^2     54.660056
# 159              exter_qual external_feature     93.921346
# 160              exter_qual bldg_type_TwnhsE    -33.758832
# 161               exter_qual bldg_type_Twnhs      0.000000
# 162              exter_qual bldg_type_2fmCon      0.000000
# 163                   exter_qual is_hip_roof   -124.266940
# 164                  exter_qual mas_vnr_area     -1.241379
# 165                    exter_qual functional   1465.411337
# 166                  exter_qual lot_frontage     -3.877172
# 167                      exter_qual lot_area     -0.010557
# 168          exter_qual developed_outside_sf     -1.679830
# 169               exter_qual garage_fin*sqft     -0.197261
# 170                   exter_qual garage_cars    156.127559
# 171                   exter_qual paved_drive    483.696031
# 172                     exter_qual bsmt_qual    -84.575072
# 173              exter_qual bsmt_type*sf_all     -0.018502
# 174                 exter_qual bsmt_exposure    113.310332
# 175                    exter_qual heating_qc     47.361237
# 176                  exter_qual kitchen_qual      9.562431
# 177                  exter_qual fireplace_qu    -51.411046
# 178            exter_qual quality_above_sqft      1.412915
# 179                 exter_qual totrms_abvgrd    -86.360667
# 180                     exter_qual room_size     -3.544156
# 181                       external_feature^2    -22.222578
# 182        external_feature bldg_type_TwnhsE     -0.000000
# 183         external_feature bldg_type_Twnhs    385.278443
# 184        external_feature bldg_type_2fmCon   1133.248773
# 185             external_feature is_hip_roof     40.290063
# 186            external_feature mas_vnr_area     -0.605749
# 187              external_feature functional    462.532679
# 188            external_feature lot_frontage      0.499827
# 189                external_feature lot_area      0.012759
# 190    external_feature developed_outside_sf     -0.785063
# 191         external_feature garage_fin*sqft     -0.282760
# 192             external_feature garage_cars     73.097231
# 193             external_feature paved_drive    112.534625
# 194               external_feature bsmt_qual    -12.756221
# 195        external_feature bsmt_type*sf_all      0.002776
# 196           external_feature bsmt_exposure     35.285473
# 197              external_feature heating_qc     12.029613
# 198            external_feature kitchen_qual     19.003459
# 199            external_feature fireplace_qu    -23.052844
# 200      external_feature quality_above_sqft      0.473109
# 201           external_feature totrms_abvgrd    -31.035113
# 202               external_feature room_size     -0.390173
# 203                       bldg_type_TwnhsE^2     -0.000000
# 204         bldg_type_TwnhsE bldg_type_Twnhs      0.000000
# 205        bldg_type_TwnhsE bldg_type_2fmCon      0.000000
# 206             bldg_type_TwnhsE is_hip_roof     -0.000000
# 207            bldg_type_TwnhsE mas_vnr_area     -0.980002
# 208              bldg_type_TwnhsE functional     -0.000000
# 209            bldg_type_TwnhsE lot_frontage    -15.444882
# 210                bldg_type_TwnhsE lot_area      0.194259
# 211    bldg_type_TwnhsE developed_outside_sf    -11.042850
# 212         bldg_type_TwnhsE garage_fin*sqft      3.898030
# 213             bldg_type_TwnhsE garage_cars  -1613.269567
# 214             bldg_type_TwnhsE paved_drive     -0.000000
# 215               bldg_type_TwnhsE bsmt_qual     -0.000000
# 216        bldg_type_TwnhsE bsmt_type*sf_all      0.658419
# 217           bldg_type_TwnhsE bsmt_exposure     42.593078
# 218              bldg_type_TwnhsE heating_qc   -291.805223
# 219            bldg_type_TwnhsE kitchen_qual    -92.301595
# 220            bldg_type_TwnhsE fireplace_qu      0.048073
# 221      bldg_type_TwnhsE quality_above_sqft      0.147135
# 222           bldg_type_TwnhsE totrms_abvgrd    -79.072899
# 223               bldg_type_TwnhsE room_size     -3.319171
# 224                        bldg_type_Twnhs^2      0.000000
# 225         bldg_type_Twnhs bldg_type_2fmCon      0.000000
# 226              bldg_type_Twnhs is_hip_roof      0.000000
# 227             bldg_type_Twnhs mas_vnr_area     -8.757267
# 228               bldg_type_Twnhs functional     -0.000000
# 229             bldg_type_Twnhs lot_frontage    -18.591541
# 230                 bldg_type_Twnhs lot_area      1.307154
# 231     bldg_type_Twnhs developed_outside_sf    -48.311453
# 232          bldg_type_Twnhs garage_fin*sqft      0.475629
# 233              bldg_type_Twnhs garage_cars      0.000000
# 234              bldg_type_Twnhs paved_drive     62.832419
# 235                bldg_type_Twnhs bsmt_qual    496.565912
# 236         bldg_type_Twnhs bsmt_type*sf_all     -0.793253
# 237            bldg_type_Twnhs bsmt_exposure      0.000000
# 238               bldg_type_Twnhs heating_qc    608.093158
# 239             bldg_type_Twnhs kitchen_qual      0.000000
# 240             bldg_type_Twnhs fireplace_qu      0.000000
# 241       bldg_type_Twnhs quality_above_sqft      0.641828
# 242            bldg_type_Twnhs totrms_abvgrd     -0.000000
# 243                bldg_type_Twnhs room_size     -0.644532
# 244                       bldg_type_2fmCon^2      0.000000
# 245             bldg_type_2fmCon is_hip_roof      0.000000
# 246            bldg_type_2fmCon mas_vnr_area     46.734226
# 247              bldg_type_2fmCon functional      0.000000
# 248            bldg_type_2fmCon lot_frontage   -120.534522
# 249                bldg_type_2fmCon lot_area     -0.383417
# 250    bldg_type_2fmCon developed_outside_sf     24.052028
# 251         bldg_type_2fmCon garage_fin*sqft    -11.366884
# 252             bldg_type_2fmCon garage_cars      0.000000
# 253             bldg_type_2fmCon paved_drive   1072.632264
# 254               bldg_type_2fmCon bsmt_qual   1895.766893
# 255        bldg_type_2fmCon bsmt_type*sf_all     -1.326712
# 256           bldg_type_2fmCon bsmt_exposure      0.000000
# 257              bldg_type_2fmCon heating_qc   2417.083203
# 258            bldg_type_2fmCon kitchen_qual     -0.000000
# 259            bldg_type_2fmCon fireplace_qu     -0.000000
# 260      bldg_type_2fmCon quality_above_sqft     -0.556932
# 261           bldg_type_2fmCon totrms_abvgrd    125.444642
# 262               bldg_type_2fmCon room_size     -2.236786
# 263                            is_hip_roof^2     -0.000000
# 264                 is_hip_roof mas_vnr_area     -3.727461
# 265                   is_hip_roof functional    797.521755
# 266                 is_hip_roof lot_frontage    -20.062493
# 267                     is_hip_roof lot_area      0.186829
# 268         is_hip_roof developed_outside_sf     -4.186708
# 269              is_hip_roof garage_fin*sqft     -1.551522
# 270                  is_hip_roof garage_cars    374.318879
# 271                  is_hip_roof paved_drive     -0.000000
# 272                    is_hip_roof bsmt_qual     96.093432
# 273             is_hip_roof bsmt_type*sf_all     -0.318047
# 274                is_hip_roof bsmt_exposure    134.934914
# 275                   is_hip_roof heating_qc    338.463100
# 276                 is_hip_roof kitchen_qual     24.703841
# 277                 is_hip_roof fireplace_qu   -556.232964
# 278           is_hip_roof quality_above_sqft      1.870418
# 279                is_hip_roof totrms_abvgrd    -52.418066
# 280                    is_hip_roof room_size     -2.980743
# 281                           mas_vnr_area^2     -0.005009
# 282                  mas_vnr_area functional     -0.340816
# 283                mas_vnr_area lot_frontage      0.108192
# 284                    mas_vnr_area lot_area     -0.000469
# 285        mas_vnr_area developed_outside_sf     -0.008594
# 286             mas_vnr_area garage_fin*sqft      0.004566
# 287                 mas_vnr_area garage_cars     -0.620407
# 288                 mas_vnr_area paved_drive     -3.120727
# 289                   mas_vnr_area bsmt_qual      0.966827
# 290            mas_vnr_area bsmt_type*sf_all     -0.000045
# 291               mas_vnr_area bsmt_exposure      1.920649
# 292                  mas_vnr_area heating_qc     -1.084399
# 293                mas_vnr_area kitchen_qual      0.592183
# 294                mas_vnr_area fireplace_qu      0.510822
# 295          mas_vnr_area quality_above_sqft      0.000165
# 296               mas_vnr_area totrms_abvgrd     -0.291765
# 297                   mas_vnr_area room_size     -0.008704
# 298                             functional^2      0.000000
# 299                  functional lot_frontage     49.175888
# 300                      functional lot_area      0.063343
# 301          functional developed_outside_sf     -3.980891
# 302               functional garage_fin*sqft     -3.812738
# 303                   functional garage_cars    138.576855
# 304                   functional paved_drive    576.553166
# 305                     functional bsmt_qual     96.349467
# 306              functional bsmt_type*sf_all      0.171774
# 307                 functional bsmt_exposure   -118.345766
# 308                    functional heating_qc    435.577924
# 309                  functional kitchen_qual    -40.535110
# 310                  functional fireplace_qu   -355.746533
# 311            functional quality_above_sqft      4.581951
# 312                 functional totrms_abvgrd   -245.149028
# 313                     functional room_size     -2.487016
# 314                           lot_frontage^2     -0.296296
# 315                    lot_frontage lot_area     -0.000616
# 316        lot_frontage developed_outside_sf      0.004627
# 317             lot_frontage garage_fin*sqft     -0.007486
# 318                 lot_frontage garage_cars      2.621624
# 319                 lot_frontage paved_drive     26.379379
# 320                   lot_frontage bsmt_qual     -3.357768
# 321            lot_frontage bsmt_type*sf_all     -0.004897
# 322               lot_frontage bsmt_exposure     -0.116125
# 323                  lot_frontage heating_qc      3.215784
# 324                lot_frontage kitchen_qual      5.631752
# 325                lot_frontage fireplace_qu      0.533778
# 326          lot_frontage quality_above_sqft      0.015575
# 327               lot_frontage totrms_abvgrd     -2.096431
# 328                   lot_frontage room_size      0.045294
# 329                               lot_area^2     -0.000002
# 330            lot_area developed_outside_sf      0.000252
# 331                 lot_area garage_fin*sqft     -0.000109
# 332                     lot_area garage_cars      0.024938
# 333                     lot_area paved_drive      0.099301
# 334                       lot_area bsmt_qual     -0.002651
# 335                lot_area bsmt_type*sf_all     -0.000002
# 336                   lot_area bsmt_exposure      0.002689
# 337                      lot_area heating_qc      0.001185
# 338                    lot_area kitchen_qual      0.001858
# 339                    lot_area fireplace_qu     -0.000434
# 340              lot_area quality_above_sqft      0.000003
# 341                   lot_area totrms_abvgrd     -0.006697
# 342                       lot_area room_size      0.000262
# 343                   developed_outside_sf^2      0.002273
# 344     developed_outside_sf garage_fin*sqft     -0.001559
# 345         developed_outside_sf garage_cars     -0.071635
# 346         developed_outside_sf paved_drive     -1.781997
# 347           developed_outside_sf bsmt_qual      0.800003
# 348    developed_outside_sf bsmt_type*sf_all     -0.000624
# 349       developed_outside_sf bsmt_exposure      1.153630
# 350          developed_outside_sf heating_qc     -0.068197
# 351        developed_outside_sf kitchen_qual      1.046546
# 352        developed_outside_sf fireplace_qu      1.252999
# 353  developed_outside_sf quality_above_sqft      0.000760
# 354       developed_outside_sf totrms_abvgrd     -0.930036
# 355           developed_outside_sf room_size      0.018154
# 356                        garage_fin*sqft^2      0.000283
# 357              garage_fin*sqft garage_cars     -0.382227
# 358              garage_fin*sqft paved_drive     -1.404994
# 359                garage_fin*sqft bsmt_qual      0.367162
# 360         garage_fin*sqft bsmt_type*sf_all      0.000230
# 361            garage_fin*sqft bsmt_exposure      0.212043
# 362               garage_fin*sqft heating_qc     -0.579359
# 363             garage_fin*sqft kitchen_qual      0.289837
# 364             garage_fin*sqft fireplace_qu     -0.019825
# 365       garage_fin*sqft quality_above_sqft      0.000674
# 366            garage_fin*sqft totrms_abvgrd     -0.205375
# 367                garage_fin*sqft room_size     -0.000049
# 368                            garage_cars^2    157.818377
# 369                  garage_cars paved_drive   -485.394798
# 370                    garage_cars bsmt_qual     30.191839
# 371             garage_cars bsmt_type*sf_all      0.007640
# 372                garage_cars bsmt_exposure      0.000000
# 373                   garage_cars heating_qc    -68.597243
# 374                 garage_cars kitchen_qual    133.765092
# 375                 garage_cars fireplace_qu    -35.480146
# 376           garage_cars quality_above_sqft      0.423316
# 377                garage_cars totrms_abvgrd    -77.328150
# 378                    garage_cars room_size     -1.286076
# 379                            paved_drive^2    127.886298
# 380                    paved_drive bsmt_qual   -309.358911
# 381             paved_drive bsmt_type*sf_all     -0.112377
# 382                paved_drive bsmt_exposure     25.026488
# 383                   paved_drive heating_qc    286.471326
# 384                 paved_drive kitchen_qual     10.084787
# 385                 paved_drive fireplace_qu   -186.847389
# 386           paved_drive quality_above_sqft      0.870068
# 387                paved_drive totrms_abvgrd     -0.000000
# 388                    paved_drive room_size      2.135562
# 389                              bsmt_qual^2   -178.133990
# 390               bsmt_qual bsmt_type*sf_all      0.031406
# 391                  bsmt_qual bsmt_exposure     16.853738
# 392                     bsmt_qual heating_qc     31.309009
# 393                   bsmt_qual kitchen_qual     72.942294
# 394                   bsmt_qual fireplace_qu    -24.990081
# 395             bsmt_qual quality_above_sqft      0.388904
# 396                  bsmt_qual totrms_abvgrd      4.717988
# 397                      bsmt_qual room_size     -1.107962
# 398                       bsmt_type*sf_all^2      0.000022
# 399           bsmt_type*sf_all bsmt_exposure     -0.069811
# 400              bsmt_type*sf_all heating_qc     -0.041896
# 401            bsmt_type*sf_all kitchen_qual      0.041222
# 402            bsmt_type*sf_all fireplace_qu      0.099179
# 403      bsmt_type*sf_all quality_above_sqft     -0.000090
# 404           bsmt_type*sf_all totrms_abvgrd     -0.036569
# 405               bsmt_type*sf_all room_size      0.000223
# 406                          bsmt_exposure^2    -46.922026
# 407                 bsmt_exposure heating_qc     -9.623803
# 408               bsmt_exposure kitchen_qual     42.115868
# 409               bsmt_exposure fireplace_qu    133.377866
# 410         bsmt_exposure quality_above_sqft      0.155696
# 411              bsmt_exposure totrms_abvgrd    -61.133270
# 412                  bsmt_exposure room_size     -0.226155
# 413                             heating_qc^2      8.812859
# 414                  heating_qc kitchen_qual    -79.979836
# 415                  heating_qc fireplace_qu   -134.472841
# 416            heating_qc quality_above_sqft      0.372006
# 417                 heating_qc totrms_abvgrd     29.345459
# 418                     heating_qc room_size      0.879119
# 419                           kitchen_qual^2    -27.271932
# 420                kitchen_qual fireplace_qu    -18.503509
# 421          kitchen_qual quality_above_sqft     -0.007609
# 422               kitchen_qual totrms_abvgrd      8.577891
# 423                   kitchen_qual room_size      0.300300
# 424                           fireplace_qu^2      6.268013
# 425          fireplace_qu quality_above_sqft      0.109382
# 426               fireplace_qu totrms_abvgrd    -47.623052
# 427                   fireplace_qu room_size      0.523770
# 428                     quality_above_sqft^2      0.000226
# 429         quality_above_sqft totrms_abvgrd     -0.133025
# 430             quality_above_sqft room_size      0.001059
# 431                          totrms_abvgrd^2     28.039617
# 432                  totrms_abvgrd room_size     -1.067992
# 433                              room_size^2      0.033644

# %% [markdown]
# # Ridge Model

# %%
#create pipeline for ridge model
pipe_ridge = Pipeline([
    ('sc', StandardScaler()),
    ('ridge', Ridge())
])

# %%
#create parameters for gridsearch
ridge_params1 = {'ridge__alpha':np.logspace(-1, 5, 500),
               'ridge__max_iter':[10000]}

# %%
#apply pipeline and gridsearch to GridSearchCV
pipe_ridge_gridsearch = GridSearchCV(
                                pipe_ridge, 
                                param_grid=ridge_params1,
                            )

# %%
#fit best result from grid search
pipe_ridge_gridsearch.fit(X_train, y_train)
pipe_ridge_gridsearch.best_estimator_
# Out:
# Pipeline(steps=[('sc', StandardScaler()),
#                 ('ridge', Ridge(alpha=16.766750345276993, max_iter=10000))])

# %%
pipe_ridge_gridsearch.best_score_ #this models score
# Out:
# 0.8922787950009882

# %%
preds_ridge = pipe_ridge_gridsearch.predict(X_test)

# %%
ames_eval['saleprice_ridge'] = preds_ridge
ridge_submission = ames_eval[['id', 'saleprice_ridge']]
# Out:
# <ipython-input-78-ff1c48c8b7c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ames_eval['saleprice'] = preds

# %%
ridge_submission.head(3)
# Out:
#      id      saleprice
# 0  2658  128839.292381
# 1  2718  164153.893323
# 2  2414  224061.479093

# %%
# Not using ridge files

# %%
#ridge submission file
#submission.to_csv('../datasets/kaggle_ridge_submission.csv', index = False)

# %% [markdown]
# # ElasticNetCV Model --best of both worlds

# %%
pipe_mario = Pipeline([
            ('poly', PolynomialFeatures(degree=3)),
            ('sc', StandardScaler()),
            ('elasticnet', ElasticNet())
                        ])

# %%
parameters_mario = {'elasticnet__alpha': np.logspace(-1, 4, 75),
                      'elasticnet__normalize': [True, False],
                      'elasticnet__selection': ['cyclic', 'random'],
                        'elasticnet__max_iter': [10000],
                        'elasticnet__tol': [.1]
                       }

# %%
elastic_net_model = GridSearchCV(
                pipe_mario, 
           param_grid= parameters_mario)
elastic_net_model.fit(X_train, y_train)
elastic_net_model.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-0a8273b524d9> in <module>
#       2                 pipe_mario,
#       3            param_grid= parameters_mario)
# ----> 4 elastic_net_model.fit(X_train, y_train)
#       5 elastic_net_model.best_estimator_
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, sample_weight, check_input)
#     830                 this_Xy = None
#     831             _, this_coef, this_dual_gap, this_iter = \
# --> 832                 self.path(X, y[:, k],
#     833                           l1_ratio=self.l1_ratio, eps=None,
#     834                           n_alphas=None, alphas=[alpha],
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     527                 tol, rng, random, positive)
#     528         elif precompute is False:
# --> 529             model = cd_fast.enet_coordinate_descent(
#     530                 coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random,
#     531                 positive)
#
# KeyboardInterrupt:

# %%
elastic_net_model.best_score_

# %%
preds_elastic_net_model = elastic_net_model.predict(X_test)

# %%
ames_eval['saleprice_elasticnet'] = preds_elastic_net_model
submission = ames_eval[['id', 'saleprice_elasticnet']]
submission.head(3)

# %%
#elastic net submission
submission.to_csv('../datasets/kaggle_elasticnet_submission.csv', index = False)
